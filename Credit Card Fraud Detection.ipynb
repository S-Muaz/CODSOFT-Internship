# %% [markdown]
# <h1> Credit Card Fraud Detection :</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
ccdf=pd.read_csv("creditcard.csv")

# %%
ccdf.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
ccdf.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# <h3>DATA PREPROCESSING :</h3>

# %%
ccdf.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
ccdf['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# <h4>We observe that there is an imbalance in our dataset hence we redefine our Dataframe :</h4>

# %%
normal=ccdf[ccdf.Class==0]

# %%
fraud=ccdf[ccdf.Class==1]

# %%
print(normal.shape)
# Out:
# (284315, 31)

# %%
print(fraud.shape)
# Out:
# (492, 31)

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
ccdf.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
normal_sample=normal.sample(n=492)

# %% [markdown]
# <h4>Creating Balanced Dataset :</h4>

# %%
new_file=pd.concat([normal_sample,fraud],axis=0)

# %%
new_file.head(10)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 37001    38764.0 -0.370598  0.571503  1.785542  0.290973  0.320251  0.217086
# 251172  155254.0 -0.744711  0.420181  0.122854 -2.287762  0.231387  0.029968
# 166569  118169.0 -1.300136  1.194822  1.445643  0.402648  0.640644  0.999781
# 218279  141246.0  2.074233 -0.895670 -1.489598 -0.327364 -0.315111 -0.192639
# 42961    41314.0 -0.868110  0.523556  1.732978  0.954978  0.492438  0.102452
# 110555   71872.0 -3.331873 -3.011615 -0.494158 -0.846347  6.492788  0.844762
# 144357   86059.0 -0.312240  0.782527  0.658743 -0.625691  0.840692 -0.106744
# 172089  120954.0 -0.149937 -0.110410 -0.292518 -1.930318 -0.834613  0.146244
# 266122  162195.0 -0.486100  0.717031  0.392562 -0.881145  1.031163 -0.320895
# 126170   77950.0  1.179409 -0.521150  0.980805 -0.680598 -1.345802 -0.585016
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
new_file['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_file.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94749.168699 -0.110804 -0.064273  0.064047 -0.075763  0.136337
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.145960  0.026834  0.005671  0.026708  ... -0.019862  0.042954
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.013884  0.010699  0.011325  0.026438 -0.000898  0.016522  0.001289
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       99.891809
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X=new_file.drop(columns='Class',axis=1)

# %%
Y=new_file['Class']

# %% [markdown]
# <h4>Once DataFrame is ready we split it into training and testing</h4>
# <h5>Train Data : 80% </h5>
# <h5>Test Data :  20%</h5>

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
model=LogisticRegression(max_iter=100)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# <h4>Making Predictions :</h4>

# %%
X_train_prediction=model.predict(X_train)

# %%
training_data_acuracy=accuracy_score(X_train_prediction,y_train)*100

# %% [markdown]
# <h4>Training Accuracy :</h4>

# %%
print(f"Training Data Accuracy: {training_data_acuracy}%")
# Out:
# Training Data Accuracy: 93.90088945362135%

# %%
X_test_prediction=model.predict(X_test)

# %%
test_data_accuracy=accuracy_score(X_test_prediction,y_test)*100

# %% [markdown]
# <h4>Testing Accuracy :</h4>

# %%
print(f"Test Data Accuracy: {test_data_accuracy}%")
# Out:
# Test Data Accuracy: 91.37055837563452%
